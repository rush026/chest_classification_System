# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
model.save_weights("models/covid_chest_xray_model.weights.h5")

from google.colab import files
files.download("models/covid_chest_xray_model.weights.h5")
files.download("models/class_indices.json")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_18498/2622265011.py in <cell line: 0>()
# ----> 1 model.save_weights("models/covid_chest_xray_model.weights.h5")
#       2
#       3 from google.colab import files
#       4 files.download("models/covid_chest_xray_model.weights.h5")
#       5 files.download("models/class_indices.json")
#
# NameError: name 'model' is not defined

# %%
# %whos
# Out:
# Interactive namespace is empty.

# %%
import os
print(os.path.exists("data/subset"))
print(os.path.exists("data/COVID-19_Radiography_Dataset"))
# Out:
# False
# False

# %%
import tensorflow as tf
print(tf.config.list_physical_devices('GPU'))
# Out:
# []
